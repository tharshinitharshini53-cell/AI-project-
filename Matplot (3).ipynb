# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.plot(x, y)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Simple line graph")
plt.show()

# %%
import pandas as pd
df = pd.read_csv("C://Users//E DHANASRI//Downloads//data_core//data_core.csv")
Temparature=df['Temparature']
Humidity=df['Humidity']
plt.plot(Temparature, Humidity, marker='o')
plt.title("Temparature vs Humidity")
plt.xlabel("Temparature")
plt.ylabel("Humidity")
plt.show()

# %%
plt.scatter(df['Nitrogen'], df['Potassium'])
plt.title("Nitrogen vs Potassium")
plt.xlabel("Nitrogen")
plt.ylabel("Potassium")
plt.show()

# %%
Moisture_soil = df.groupby('Moisture')['Soil Type'].mean()

plt.bar(Moisture.index, Soil Type.values)
plt.title("Moisture vs Soil_Type")
plt.xlabel("Moisture")
plt.ylabel("Soil Type")
plt.xticks(rotation=45)
plt.show()
# Out:
#   Cell In[23], line 3
#     plt.bar(Moisture.index, Soil Type.values)
#                             ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
